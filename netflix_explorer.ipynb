# %% [markdown]
# # 📊 Netflix Data Explorer
#
# **Project Description:**
# This notebook analyzes Netflix's global catalogue using pandas. It covers content distribution across countries, content types, genre popularity, director contributions, and release trends.
#
# **Dataset:** [Netflix Titles on Kaggle](https://www.kaggle.com/datasets/shivamb/netflix-shows)

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", 25)

# %%
netflix = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# ## Previewing Data

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## Cleaning Data

# %%
netflix.fillna(np.nan)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.isna().sum()
#Therefore there are alot of missing values which need to be dropped
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
netflix.dropna(inplace=True)

# %%
#We finished missing value Treatment now we need to find if there are any duplicates
netflix.duplicated().sum()
#Therefore no duplicated values
# Out:
# 0

# %% [markdown]
# ## Q1. Top 10 Countries with Most Shows

# %%
top_10_countries = netflix['country'].value_counts().head(10).index.to_list()
print(top_10_countries)
# Out:
# ['United States', 'India', 'United Kingdom', 'Canada', 'Spain', 'Egypt', 'Nigeria', 'Japan', 'Turkey', 'Indonesia']

# %% [markdown]
# ## Q2. Count of movies vs tv shows

# %%
netflix
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
netflix['type'].value_counts()
# Out:
# type
# Movie      5185
# TV Show     147
# Name: count, dtype: int64

# %% [markdown]
# ## Q3. Trend of content release over years

# %%
release_trend = pd.DataFrame(netflix['release_year'].value_counts())
release_trend = release_trend.rename(columns={'count':'total_titles'})
print(release_trend)
# Out:
#               total_titles
# release_year
# 2017                   657
# 2018                   648
# 2016                   577
# 2019                   519
# 2020                   442
# ...                    ...
# 1946                     1
# 1961                     1
# 1942                     1
# 1947                     1
# 1944                     1
#
# [72 rows x 1 columns]

# %% [markdown]
# ## Q4. Most frequent genres (based on listed_in)

# %%
genre_list = netflix['listed_in'].str.split(', ')

from itertools import chain

new_genre_list = list(chain.from_iterable(genre_list))
popular_genre = pd.Series(new_genre_list).value_counts()
print(popular_genre)
# Out:
# International Movies            2369
# Dramas                          2293
# Comedies                        1553
# Action & Adventure               806
# Independent Movies               740
# Romantic Movies                  579
# Thrillers                        547
# Children & Family Movies         503
# Documentaries                    391
# Horror Movies                    336
# Stand-Up Comedy                  294
# Music & Musicals                 292
# Sci-Fi & Fantasy                 236
# Sports Movies                    156
# Classic Movies                   108
# International TV Shows            87
# LGBTQ Movies                      80
# Cult Movies                       69
# Anime Features                    61
# Faith & Spirituality              58
# TV Dramas                         52
# Crime TV Shows                    38
# TV Comedies                       30
# British TV Shows                  21
# Romantic TV Shows                 21
# ...

# %% [markdown]
# ## Q5. Top directors by volume

# %%
netflix
directors = netflix['director'].str.split(', ')
directors = list(chain.from_iterable(directors))
top_10_directors = pd.Series(directors).value_counts().head(10)
top_10_directors
# Out:
# Jan Suter              21
# Raúl Campos            19
# Jay Karas              15
# Marcus Raboy           15
# Cathy Garcia-Molina    13
# Youssef Chahine        12
# Martin Scorsese        12
# Jay Chapman            12
# Steven Spielberg       11
# Don Michael Paul       10
# Name: count, dtype: int64

# %% [markdown]
# ## Exporting as CSV

# %%
netflix.to_csv("netflix_analysis.csv", index=False)
